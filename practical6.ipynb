# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasuresh1450-ai/Python-For-Data-Science-/blob/main/practical6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practical no:6

# %% [markdown]
# Name:Divya Suresh Gaikwad,
# Class-Sy-A,Roll no:64.

# %% [markdown]
# Aim:To study and implement web scraping in Python using the Requests library and BeautifulSoup for extracting and parsing data from
# web pages.

# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import urllib3

# %%
import requests
url = "https://quotes.toscrape.com"
response = requests.get(url)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "https://quotes.toscrape.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "https://quotes.toscrape.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.title.text)
# Out:
# Quotes to Scrape

# %%
import requests
from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

quotes = soup.find_all("span", class_="text")

for q in quotes:
    print(q.get_text())
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %%
import requests
url = "https://quotes.toscrape.com"
response = requests.get(url)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
#
#
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
import requests
from bs4 import BeautifulSoup
url = "https://quotes.toscrape.com"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

authors = soup.find_all("small", class_="author")

for author in authors:
    print(author.get_text())
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %% [markdown]
# 1.What is web scraping? Explain the role of the Requests library in web scraping.
#
# Web scraping is the process of automatically collecting data from websites using programs instead of manually copying the data. It iscommonly used to extract information such as: text,images,links,tables The Requests library is used to send an HTTP request to a websiteand retrieve the webpage content. It helps in:sending GET requests,receiving the HTML source code Example: import requestsresponse =requests.get("
# https://quotes.toscrape.com")print(response.text)
# Here, response.text gives the HTML content of the webpage.
#
#
#
# 2.What is BeautifulSoup? How does it help in parsing HTML?
#
# BeautifulSoup is a Python library used for parsing HTML and XML documents. It converts raw HTML code into a structured format that canbe easily searched and navigated. It helps in: finding specific tags,extracting text locating elements by class or id,retrieving links andattributes Example: from bs4 import BeautifulSoupsoup = BeautifulSoup(response.text, "html.parser") This parses the HTML document sowe can use methods like find() and find_all().
#
#
#
# 3.Differentiate between web scraping and web crawling.
#
# Web ScrapingWeb CrawlingUsed to extract specific data from websitesUsed to browse multiple webpages automaticallyFocuses oncollecting informationFocuses on discovering URLs and webpagesUsually targets one or a few pagesCovers large numbers ofpagesExample: extracting quotes from a webpageExample: search engine bots like Google In simple words, scraping means collectingdata, while crawling means visiting pages automatically.
#
#
#
# 4.What are the commonly used methods in BeautifulSoup?
# find() → finds the first matching tag find_all() → finds all matching tag get_text() → extracts text content select() → uses CSS selectorsget() → gets attribute values prettify() → formats HTML properly Example: soup.find("title")soup.find_all("a")soup.get_text()
#
#
#
# 5.What are the ethical and legal considerations in web scraping?
#
# While performing web scraping, the following points should be considered:Respect website terms and conditions,Check robots.txtrules,Do not overload the server with too many requests,Avoid scraping private or sensitive data,Give proper credit if data is reused,Do notuse scraped data for illegal purposes. Ethical scraping means collecting data responsibly and legally.
