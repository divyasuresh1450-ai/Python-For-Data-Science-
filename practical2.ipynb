# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasuresh1450-ai/Python-For-Data-Science-/blob/main/practical2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Divya Suresh Gaikwad
# Roll no:SY-A -64

# %% [markdown]
# Practical no:2

# %% [markdown]
# AIM:To acquire the dataset from a CSV file and perform data cleaning operations such as checking null values, duplicates, and datasetstructure using Python Pandas

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bcddbdb-50ad-4bb5-81a0-902ea6b93275" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bcddbdb-50ad-4bb5-81a0-902ea6b93275">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("aistudent.csv")
print(df)
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 0             1   15  Female         College   Hyderabad      Copilot
# 1             2   21  Female      University     Chennai      Copilot
# 2             3   22    Male      University   Bangalore       Gemini
# 3             4   22    Male         College   Hyderabad      ChatGPT
# 4             5   22    Male         College   Hyderabad       Gemini
# ..          ...  ...     ...             ...         ...          ...
# 395          96   16  Female          School      Multan    Grammarly
# 396          97   25  Female          School  Faisalabad       Gemini
# 397          98   17  Female         College  Faisalabad       Gemini
# 398          99   15  Female         College      Lahore    Notion AI
# 399         100   24  Female          School      Multan       Gemini
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# ...

# %%
print
(df.head())
# Out:
#    Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 0           1   15  Female         College  Hyderabad      Copilot
# 1           2   21  Female      University    Chennai      Copilot
# 2           3   22    Male      University  Bangalore       Gemini
# 3           4   22    Male         College  Hyderabad      ChatGPT
# 4           5   22    Male         College  Hyderabad       Gemini
#
#    Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 0                1.1  Learning   Slight Decline             Medium
# 1                1.7    Coding   Slight Decline               High
# 2                1.5  Learning         Improved                Low
# 3                3.8  Research         Improved                Low
# 4                5.2    Coding   Slight Decline                Low

# %%
print
(df.tail())
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 395          96   16  Female          School      Multan    Grammarly
# 396          97   25  Female          School  Faisalabad       Gemini
# 397          98   17  Female         College  Faisalabad       Gemini
# 398          99   15  Female         College      Lahore    Notion AI
# 399         100   24  Female          School      Multan       Gemini
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# 395                5.0  Learning   Slight Decline             Medium
# 396                1.9   Writing        No Change             Medium
# 397                2.9   Writing        No Change                Low
# 398                3.6  Homework   Slight Decline               High
# 399                2.7  Learning         Improved               High

# %%
print
(df.shape)
# Out:
# (400, 10)

# %%
print
(df.columns)
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Education_Level', 'City',
#        'AI_Tool_Used', 'Daily_Usage_Hours', 'Purpose', 'Impact_on_Grades',
#        'Satisfaction_Level'],
#       dtype='object')

# %%
print
(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          400 non-null    int64
#  1   Age                 400 non-null    int64
#  2   Gender              400 non-null    object
#  3   Education_Level     400 non-null    object
#  4   City                400 non-null    object
#  5   AI_Tool_Used        400 non-null    object
#  6   Daily_Usage_Hours   400 non-null    float64
#  7   Purpose             400 non-null    object
#  8   Impact_on_Grades    400 non-null    object
#  9   Satisfaction_Level  400 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 31.4+ KB

# %%
print
(df.isnull().
sum
())
# Out:
# Student_ID            0
# Age                   0
# Gender                0
# Education_Level       0
# City                  0
# AI_Tool_Used          0
# Daily_Usage_Hours     0
# Purpose               0
# Impact_on_Grades      0
# Satisfaction_Level    0
# dtype: int64

# %%
print
(df.duplicated().
sum
())
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()
print
(df)
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 0             1   15  Female         College   Hyderabad      Copilot
# 1             2   21  Female      University     Chennai      Copilot
# 2             3   22    Male      University   Bangalore       Gemini
# 3             4   22    Male         College   Hyderabad      ChatGPT
# 4             5   22    Male         College   Hyderabad       Gemini
# ..          ...  ...     ...             ...         ...          ...
# 395          96   16  Female          School      Multan    Grammarly
# 396          97   25  Female          School  Faisalabad       Gemini
# 397          98   17  Female         College  Faisalabad       Gemini
# 398          99   15  Female         College      Lahore    Notion AI
# 399         100   24  Female          School      Multan       Gemini
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# ...

# %%
print
(df.describe())
# Out:
#        Student_ID         Age  Daily_Usage_Hours
# count  400.000000  400.000000         400.000000
# mean   125.500000   19.425000           2.933750
# std     87.906592    2.991948           1.589939
# min      1.000000   15.000000           0.500000
# 25%     50.750000   17.000000           1.575000
# 50%    100.500000   19.500000           2.900000
# 75%    200.250000   22.000000           4.200000
# max    300.000000   25.000000           6.000000

# %%
print
(df[
"Age"
].mean())
# Out:
# np.float64(19.425)

# %%
print
(df[
"Daily_Usage_Hours"
].
max
())
# Out:
# 6.0

# %%
print
(df[
"Daily_Usage_Hours"
].
min
())
# Out:
# 0.5

# %%
print
(df[
"Gender"
].value_counts())
# Out:
# Gender
# Male      205
# Female    195
# Name: count, dtype: int64

# %%
print
(df[
"City"
].value_counts())
# Out:
# City
# Delhi         37
# Bangalore     32
# Chennai       32
# Jaipur        32
# Pune          30
# Kolkata       30
# Lucknow       29
# Multan        29
# Ahmedabad     28
# Hyderabad     27
# Mumbai        23
# Lahore        22
# Islamabad     18
# Faisalabad    17
# Karachi       14
# Name: count, dtype: int64

# %%
print
(df[
"AI_Tool_Used"
].value_counts())
# Out:
# AI_Tool_Used
# Gemini       129
# ChatGPT      124
# Copilot      108
# Grammarly     24
# Notion AI     15
# Name: count, dtype: int64

# %%
print
(df[df[
"Purpose"
] ==
"Coding"
])
# Out:
#      Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 1             2   21  Female      University    Chennai      Copilot
# 4             5   22    Male         College  Hyderabad       Gemini
# 5             6   17    Male         College      Delhi      ChatGPT
# 6             7   15  Female          School       Pune      Copilot
# 10           11   22    Male          School     Jaipur      ChatGPT
# ..          ...  ...     ...             ...        ...          ...
# 374          75   16    Male      University     Lahore    Grammarly
# 376          77   19  Female         College  Islamabad      ChatGPT
# 384          85   25  Female         College  Islamabad    Notion AI
# 385          86   19    Male         College    Karachi       Gemini
# 392          93   21    Male          School     Multan    Notion AI
#
#      Daily_Usage_Hours Purpose Impact_on_Grades Satisfaction_Level
# 1                  1.7  Coding   Slight Decline               High
# ...

# %%
print
(df[df[
"Age"
] >
20
])
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 1             2   21  Female      University     Chennai      Copilot
# 2             3   22    Male      University   Bangalore       Gemini
# 3             4   22    Male         College   Hyderabad      ChatGPT
# 4             5   22    Male         College   Hyderabad       Gemini
# 10           11   22    Male          School      Jaipur      ChatGPT
# ..          ...  ...     ...             ...         ...          ...
# 392          93   21    Male          School      Multan    Notion AI
# 393          94   21  Female          School   Islamabad    Grammarly
# 394          95   23    Male          School      Multan       Gemini
# 396          97   25  Female          School  Faisalabad       Gemini
# 399         100   24  Female          School      Multan       Gemini
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# ...

# %%
print
(df[[
"Age"
,
"Gender"
,
"AI_Tool_Used"
]])
# Out:
#      Age  Gender AI_Tool_Used
# 0     15  Female      Copilot
# 1     21  Female      Copilot
# 2     22    Male       Gemini
# 3     22    Male      ChatGPT
# 4     22    Male       Gemini
# ..   ...     ...          ...
# 395   16  Female    Grammarly
# 396   25  Female       Gemini
# 397   17  Female       Gemini
# 398   15  Female    Notion AI
# 399   24  Female       Gemini
#
# [400 rows x 3 columns]

# %%
print
(df[df[
"Age"
] >
20
])
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 1             2   21  Female      University     Chennai      Copilot
# 2             3   22    Male      University   Bangalore       Gemini
# 3             4   22    Male         College   Hyderabad      ChatGPT
# 4             5   22    Male         College   Hyderabad       Gemini
# 10           11   22    Male          School      Jaipur      ChatGPT
# ..          ...  ...     ...             ...         ...          ...
# 392          93   21    Male          School      Multan    Notion AI
# 393          94   21  Female          School   Islamabad    Grammarly
# 394          95   23    Male          School      Multan       Gemini
# 396          97   25  Female          School  Faisalabad       Gemini
# 399         100   24  Female          School      Multan       Gemini
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# ...

# %%
print
(df[[
"Age"
,
"Gender"
,
"AI_Tool_Used"
]])
# Out:
#      Age  Gender AI_Tool_Used
# 0     15  Female      Copilot
# 1     21  Female      Copilot
# 2     22    Male       Gemini
# 3     22    Male      ChatGPT
# 4     22    Male       Gemini
# ..   ...     ...          ...
# 395   16  Female    Grammarly
# 396   25  Female       Gemini
# 397   17  Female       Gemini
# 398   15  Female    Notion AI
# 399   24  Female       Gemini
#
# [400 rows x 3 columns]

# %%
print
(df.sort_values(
"Age"
))
# Out:
#      Student_ID  Age  Gender Education_Level        City AI_Tool_Used  \
# 18           19   15    Male          School     Kolkata      ChatGPT
# 24           25   15    Male      University       Delhi       Gemini
# 31           32   15  Female      University     Chennai       Gemini
# 27           28   15  Female          School        Pune      Copilot
# 372          73   15    Male      University  Faisalabad    Notion AI
# ..          ...  ...     ...             ...         ...          ...
# 350          51   25  Female      University  Faisalabad    Notion AI
# 337          38   25  Female          School  Faisalabad      ChatGPT
# 380          81   25  Female      University      Lahore      ChatGPT
# 353          54   25  Female          School   Islamabad    Grammarly
# 355          56   25  Female          School     Karachi    Notion AI
#
#      Daily_Usage_Hours   Purpose Impact_on_Grades Satisfaction_Level
# ...

# %%
print
(df[df[
"Purpose"
] ==
"Coding"
])
# Out:
#      Student_ID  Age  Gender Education_Level       City AI_Tool_Used  \
# 1             2   21  Female      University    Chennai      Copilot
# 4             5   22    Male         College  Hyderabad       Gemini
# 5             6   17    Male         College      Delhi      ChatGPT
# 6             7   15  Female          School       Pune      Copilot
# 10           11   22    Male          School     Jaipur      ChatGPT
# ..          ...  ...     ...             ...        ...          ...
# 374          75   16    Male      University     Lahore    Grammarly
# 376          77   19  Female         College  Islamabad      ChatGPT
# 384          85   25  Female         College  Islamabad    Notion AI
# 385          86   19    Male         College    Karachi       Gemini
# 392          93   21    Male          School     Multan    Notion AI
#
#      Daily_Usage_Hours Purpose Impact_on_Grades Satisfaction_Level
# 1                  1.7  Coding   Slight Decline               High
# ...

# %% [markdown]
# 1.
# What is data ingestion and why is it important in data science? Which Python library is commonly used for data ingestion andcleaning?
# Data ingestion is the process of collecting and importing data from different sources such as CSV files, Excel files, databases, APIs, orwebsites into a system for further analysis.It brings raw data into a usable format,Helps in storing and organizing data,Makes data readyfor analysis and machine learning,Ensures data from multiple sources can be combined.The most commonly used Python library for dataingestion and cleaning is Pandas.
#
#
# 2.Why is data cleaning necessary before performing analysis or machine learning?
# Data cleaning is necessary because real-world data often contains:Missing values,Duplicate records Incorrect values,Inconsistentformats,Extra spaces or unwanted symbols. If data is not cleaned:Results may be incorrect Model accuracy decreases,Analysis becomesmisleading.
#
#
# 3.How do you load a CSV file into a Pandas DataFrame?
# A CSV file can be loaded using the read_csv() function.
# import pandas as pd
# df = pd.read_csv("aistudent.csv") print(df)
#
#
# 4.
# What is the difference between head() and tail() functions in Pandas?
# Both functions are used to preview data. head():Displays the first 5 rows of the dataset by default. print(df.head()) tail():Displays the last 5rows of the dataset by default. print(df.tail()) Example: head() : top rows tail() : bottom rows these are useful for quickly checking thedataset structure.
#
#
# 5.
# How can you identify missing values in a dataset?
# Missing values can be identified using: isnull() isna() Example: print(df.isnull()):To count missing values in each column:print(df.isnull().sum()) This shows the number of missing values column-wise.
